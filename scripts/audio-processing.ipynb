# %%
# !pip install librosa soundfile webrtcvad pydub
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.10/dist-packages (0.10.2.post1)
# Requirement already satisfied: soundfile in /usr/local/lib/python3.10/dist-packages (0.12.1)
# Requirement already satisfied: webrtcvad in /usr/local/lib/python3.10/dist-packages (2.0.10)
# Requirement already satisfied: pydub in /usr/local/lib/python3.10/dist-packages (0.25.1)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.10/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.5.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.10/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.10/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.10/dist-packages (from soundfile) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0->soundfile) (2.22)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from lazy-loader>=0.1->librosa) (24.1)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.10/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.8.30)

# %%
import os
import numpy as np
import librosa
import soundfile as sf
from pydub import AudioSegment
from google.colab import drive
import webrtcvad
import wave
import contextlib
from datetime import datetime
import logging
from typing import Tuple, List, Optional

# %%
class AudioProcessingError(Exception):
    """Custom exception for audio processing errors."""
    pass

class AudioProcessor:
    SUPPORTED_FORMATS = {'.wav', '.mp3', '.flac'}

    def __init__(self, target_sr: int = 16000, min_segment_length: int = 20, max_segment_length: int = 30):
        """
        Initialize the audio processor with support for multiple formats.

        Args:
            target_sr: Target sample rate in Hz
            min_segment_length: Minimum segment length in seconds
            max_segment_length: Maximum segment length in seconds
        """
        try:
            if target_sr <= 0:
                raise ValueError("Target sample rate must be positive")
            if min_segment_length <= 0 or max_segment_length <= 0:
                raise ValueError("Segment lengths must be positive")
            if min_segment_length >= max_segment_length:
                raise ValueError("Minimum segment length must be less than maximum segment length")

            self.target_sr = target_sr
            self.min_segment_length = min_segment_length
            self.max_segment_length = max_segment_length
            self.vad = webrtcvad.Vad(2)  # Reduced aggressiveness to 2 for better segment detection

            logging.basicConfig(level=logging.INFO,
                              format='%(asctime)s - %(levelname)s - %(message)s')
            self.logger = logging.getLogger(__name__)

        except Exception as e:
            raise AudioProcessingError(f"Failed to initialize AudioProcessor: {str(e)}")

    def mount_drive(self) -> None:
        """
        Mount Google Drive with error handling.

        Raises:
            AudioProcessingError: If drive mounting fails
        """
        try:
            drive.mount('/content/drive')
            self.logger.info("Google Drive mounted successfully")
        except Exception as e:
            raise AudioProcessingError(f"Failed to mount Google Drive: {str(e)}")

    def get_file_format(self, file_path: str) -> str:
        """
        Get the audio file format from the file path.

        Args:
            file_path: Path to the audio file

        Returns:
            File extension including the dot

        Raises:
            AudioProcessingError: If format is not supported
        """
        file_ext = os.path.splitext(file_path)[1].lower()
        if file_ext not in self.SUPPORTED_FORMATS:
            raise AudioProcessingError(f"Unsupported audio format: {file_ext}")
        return file_ext

    def validate_file_path(self, file_path: str) -> None:
        """
        Validate if file exists and is accessible.

        Args:
            file_path: Path to the file

        Raises:
            AudioProcessingError: If file validation fails
        """
        if not os.path.exists(file_path):
            raise AudioProcessingError(f"File not found: {file_path}")
        if not os.path.isfile(file_path):
            raise AudioProcessingError(f"Not a file: {file_path}")
        if not os.access(file_path, os.R_OK):
            raise AudioProcessingError(f"File not readable: {file_path}")

    def load_audio(self, file_path: str) -> Tuple[np.ndarray, int]:
        """
        Load audio file in any supported format.

        Args:
            file_path: Path to the audio file

        Returns:
            Tuple of audio data and sample rate
        """
        try:
            self.validate_file_path(file_path)
            file_format = self.get_file_format(file_path)

            self.logger.info(f"Loading {file_format} audio file: {file_path}")

            if file_format == '.mp3':
                # Use pydub for MP3 files
                audio_segment = AudioSegment.from_mp3(file_path)
                audio_array = np.array(audio_segment.get_array_of_samples())
                # Convert to float32 and normalize
                audio_array = audio_array.astype(np.float32) / np.iinfo(np.int16).max
                if audio_segment.channels == 2:
                    audio_array = audio_array.reshape((-1, 2))
                    audio_array = np.mean(audio_array, axis=1)
                return audio_array, audio_segment.frame_rate
            else:
                # Use librosa for WAV and FLAC
                audio, sr = librosa.load(file_path, sr=None, mono=True)
                return audio, sr

        except Exception as e:
            raise AudioProcessingError(f"Failed to load audio file: {str(e)}")

    def save_segment(self, audio: np.ndarray, sr: int, filepath: str, original_format: str) -> None:
        """
        Save audio segment in the same format as the input file.

        Args:
            audio: Audio data
            sr: Sample rate
            filepath: Output file path
            original_format: Original audio format
        """
        try:
            if original_format == '.mp3':
                # Convert to int16 and save as MP3
                audio_int16 = (audio * np.iinfo(np.int16).max).astype(np.int16)
                segment = AudioSegment(
                    audio_int16.tobytes(),
                    frame_rate=sr,
                    sample_width=2,
                    channels=1
                )
                segment.export(filepath, format='mp3')
            else:
                # Save as WAV or FLAC using soundfile
                sf.write(filepath, audio, sr, format=original_format[1:])

        except Exception as e:
            raise AudioProcessingError(f"Failed to save segment: {str(e)}")

    def save_segments(self, audio: np.ndarray, sr: int, segments: List[Tuple[float, float]],
                     output_dir: str, filename_prefix: str, original_format: str) -> List[str]:
        """
        Save audio segments in the original format with sequential naming.
        """
        try:
            os.makedirs(output_dir, exist_ok=True)

            if not os.access(output_dir, os.W_OK):
                raise AudioProcessingError(f"Output directory not writable: {output_dir}")

            current_number = self.get_next_file_number(output_dir, filename_prefix)

            saved_files = []
            total_segments = len(segments)

            for idx, (start, end) in enumerate(segments):
                try:
                    start_sample = int(start * sr)
                    end_sample = int(end * sr)
                    segment = audio[start_sample:end_sample]

                    filename = f"{filename_prefix}-{current_number:03d}{original_format}"
                    filepath = os.path.join(output_dir, filename)

                    # Save segment in original format
                    self.save_segment(segment, sr, filepath, original_format)
                    saved_files.append(filename)

                    # Print progress for each saved file
                    print(f"Saved segment {current_number:03d} ({idx + 1}/{total_segments}): {filename}")
                    print(f"  Duration: {(end - start):.2f} seconds")
                    print(f"  Time range: {start:.2f}s - {end:.2f}s")
                    print("-" * 50)

                    current_number += 1

                except Exception as e:
                    self.logger.error(f"Failed to save segment {current_number}: {str(e)}")
                    continue

            if not saved_files:
                raise AudioProcessingError("No segments were successfully saved")

            return saved_files

        except Exception as e:
            raise AudioProcessingError(f"Failed to save segments: {str(e)}")

    def detect_voice_activity(self, audio: np.ndarray, sr: int) -> List[Tuple[float, float]]:
        """
        Detect segments with voice activity.

        Args:
            audio: Audio data
            sr: Sample rate

        Returns:
            List of (start, end) tuples in seconds
        """
        try:
            # Convert to 16-bit PCM
            audio_pcm = (audio * 32768).astype(np.int16)

            # Parameters for VAD
            frame_duration = 20  # Reduced from 30ms to 20ms for finer granularity
            frames_per_window = sr * frame_duration // 1000

            # Split audio into frames
            frames = []
            for i in range(0, len(audio_pcm), frames_per_window):
                frame = audio_pcm[i:i + frames_per_window]
                if len(frame) < frames_per_window:
                    frame = np.pad(frame, (0, frames_per_window - len(frame)))
                frames.append(frame.tobytes())

            if not frames:
                raise AudioProcessingError("No valid frames found in audio")

            # Detect speech in frames with smoothing
            is_speech = []
            window_size = 3  # Smoothing window size
            for i in range(0, len(frames)):
                # Get average of surrounding frames
                window_start = max(0, i - window_size)
                window_end = min(len(frames), i + window_size + 1)
                window_speeches = []
                for frame in frames[window_start:window_end]:
                    try:
                        window_speeches.append(self.vad.is_speech(frame, sr))
                    except Exception as e:
                        self.logger.warning(f"Failed to process frame: {str(e)}")
                        window_speeches.append(False)
                # Use majority vote
                is_speech.append(sum(window_speeches) > len(window_speeches) / 2)

            # Find continuous speech segments with more lenient gap filling
            segments = []
            start = None
            current_duration = 0
            silence_duration = 0
            max_silence_gap = 0.5  # Maximum silence gap to bridge (in seconds)

            for i, speech in enumerate(is_speech):
                frame_time = frame_duration / 1000  # Convert ms to seconds

                if speech:
                    if start is None:
                        start = i
                    current_duration += frame_time
                    silence_duration = 0
                else:
                    if start is not None:
                        silence_duration += frame_time
                        if silence_duration >= max_silence_gap:
                            # End segment if silence is too long
                            if current_duration >= self.min_segment_length:
                                end = i - int(silence_duration * (1000/frame_duration))
                                segments.append((
                                    start * frame_time,
                                    end * frame_time
                                ))
                                self.logger.info(f"Found segment: {start * frame_time:.2f}s - {end * frame_time:.2f}s")
                            start = None
                            current_duration = 0
                            silence_duration = 0

                # Force split if segment is too long
                if current_duration >= self.max_segment_length:
                    end = i
                    segments.append((
                        start * frame_time,
                        end * frame_time
                    ))
                    self.logger.info(f"Split long segment: {start * frame_time:.2f}s - {end * frame_time:.2f}s")
                    start = i
                    current_duration = 0
                    silence_duration = 0

            # Handle the last segment
            if start is not None and current_duration >= self.min_segment_length:
                segments.append((
                    start * frame_time,
                    len(is_speech) * frame_time
                ))
                self.logger.info(f"Final segment: {start * frame_time:.2f}s - {len(is_speech) * frame_time:.2f}s")

            if not segments:
                self.logger.warning("No voice activity segments detected")
            else:
                self.logger.info(f"Total segments detected: {len(segments)}")

            return segments

        except Exception as e:
            raise AudioProcessingError(f"Failed to detect voice activity: {str(e)}")

    def get_next_file_number(self, output_dir: str, filename_prefix: str) -> int:
        """
        Find the next available file number in the sequence.

        Args:
            output_dir: Output directory
            filename_prefix: Prefix for output filenames

        Returns:
            Next available file number

        Raises:
            AudioProcessingError: If directory access fails
        """
        try:
            if not os.path.exists(output_dir):
                return 0

            existing_files = os.listdir(output_dir)
            existing_numbers = []

            # Extract existing numbers from filenames
            for filename in existing_files:
                if filename.startswith(filename_prefix) and filename.endswith('.wav'):
                    try:
                        num_str = filename.replace(filename_prefix + '-', '').replace('.wav', '')
                        num = int(num_str)
                        existing_numbers.append(num)
                    except ValueError:
                        continue

            return max(existing_numbers + [-1]) + 1

        except Exception as e:
            raise AudioProcessingError(f"Failed to get next file number: {str(e)}")

    def process_audio_file(self, input_file: str, output_dir: str, filename_prefix: str) -> Tuple[int, List[str]]:
        """
        Process a single audio file and maintain original format.

        Args:
            input_file: Path to input audio file
            output_dir: Output directory
            filename_prefix: Prefix for output filenames

        Returns:
            Tuple of number of segments created and list of saved filenames
        """
        try:
            # Get original format
            original_format = self.get_file_format(input_file)

            # Load audio
            self.logger.info("Starting audio processing")
            audio, sr = self.load_audio(input_file)

            # Resample if necessary
            if sr != self.target_sr:
                self.logger.info(f"Resampling from {sr}Hz to {self.target_sr}Hz")
                audio = librosa.resample(audio, orig_sr=sr, target_sr=self.target_sr)
                sr = self.target_sr

            # Detect voice activity segments
            self.logger.info("Detecting voice activity")
            segments = self.detect_voice_activity(audio, sr)

            if not segments:
                self.logger.warning("No voice segments detected in the audio file")
                return 0, []

            # Save segments in original format
            self.logger.info(f"Saving segments in {original_format} format")
            saved_files = self.save_segments(audio, sr, segments, output_dir, filename_prefix, original_format)

            return len(segments), saved_files

        except Exception as e:
            raise AudioProcessingError(f"Failed to process audio file: {str(e)}")

def main():
    try:
        # Initialize processor
        processor = AudioProcessor(
            target_sr=16000,
            min_segment_length=20,
            max_segment_length=30
        )

        # Configure paths
        input_file = '/content/drive/Shareddrives/CS307-Thesis/Dataset/test-data/test_raw.mp3'  # Can be .mp3, .wav, or .flac
        output_dir = '/content/drive/Shareddrives/CS307-Thesis/Dataset/test-data/'
        filename_prefix = 'training'

        # Process audio file
        num_segments, saved_files = processor.process_audio_file(input_file, output_dir, filename_prefix)

        print(f"\nProcessing complete!")
        print(f"Created {num_segments} segments.")
        print("\nSaved files:")
        for filename in saved_files:
            print(f"- {filename}")

    except AudioProcessingError as e:
        print(f"\nError during audio processing: {str(e)}")
        logging.error(f"Audio processing failed: {str(e)}")
    except Exception as e:
        print(f"\nUnexpected error: {str(e)}")
        logging.error(f"Unexpected error: {str(e)}", exc_info=True)

if __name__ == "__main__":
    main()
# Out:
# Saved segment 000 (1/198): training-000.mp3
#   Duration: 31.10 seconds
#   Time range: 0.02s - 31.12s
# --------------------------------------------------
# Saved segment 001 (2/198): training-001.mp3
#   Duration: 30.58 seconds
#   Time range: 31.12s - 61.70s
# --------------------------------------------------
# Saved segment 002 (3/198): training-002.mp3
#   Duration: 30.58 seconds
#   Time range: 61.70s - 92.28s
# --------------------------------------------------
# Saved segment 003 (4/198): training-003.mp3
#   Duration: 31.06 seconds
#   Time range: 92.28s - 123.34s
# --------------------------------------------------
# Saved segment 004 (5/198): training-004.mp3
#   Duration: 30.26 seconds
#   Time range: 123.34s - 153.60s
# --------------------------------------------------
# Saved segment 005 (6/198): training-005.mp3
#   Duration: 30.06 seconds
#   Time range: 153.60s - 183.66s
# --------------------------------------------------
# Saved segment 006 (7/198): training-006.mp3
#   Duration: 33.70 seconds
#   Time range: 191.08s - 224.78s
# --------------------------------------------------
# Saved segment 007 (8/198): training-007.mp3
#   Duration: 31.02 seconds
#   Time range: 238.94s - 269.96s
# --------------------------------------------------
# Saved segment 008 (9/198): training-008.mp3
#   Duration: 30.48 seconds
#   Time range: 269.96s - 300.44s
# --------------------------------------------------
# Saved segment 009 (10/198): training-009.mp3
#   Duration: 30.36 seconds
#   Time range: 300.44s - 330.80s
# --------------------------------------------------
# Saved segment 010 (11/198): training-010.mp3
#   Duration: 30.12 seconds
#   Time range: 330.80s - 360.92s
# --------------------------------------------------
# Saved segment 011 (12/198): training-011.mp3
#   Duration: 32.22 seconds
#   Time range: 360.92s - 393.14s
# --------------------------------------------------
# Saved segment 012 (13/198): training-012.mp3
#   Duration: 31.76 seconds
#   Time range: 393.14s - 424.90s
# --------------------------------------------------
# Saved segment 013 (14/198): training-013.mp3
#   Duration: 30.56 seconds
#   Time range: 424.90s - 455.46s
# --------------------------------------------------
# Saved segment 014 (15/198): training-014.mp3
#   Duration: 30.22 seconds
#   Time range: 455.46s - 485.68s
# --------------------------------------------------
# Saved segment 015 (16/198): training-015.mp3
#   Duration: 30.22 seconds
#   Time range: 485.68s - 515.90s
# --------------------------------------------------
# Saved segment 016 (17/198): training-016.mp3
#   Duration: 30.14 seconds
#   Time range: 515.90s - 546.04s
# --------------------------------------------------
# Saved segment 017 (18/198): training-017.mp3
#   Duration: 30.32 seconds
#   Time range: 546.04s - 576.36s
# --------------------------------------------------
# Saved segment 018 (19/198): training-018.mp3
#   Duration: 30.96 seconds
#   Time range: 576.36s - 607.32s
# --------------------------------------------------
# Saved segment 019 (20/198): training-019.mp3
#   Duration: 32.20 seconds
#   Time range: 607.32s - 639.52s
# --------------------------------------------------
# Saved segment 020 (21/198): training-020.mp3
#   Duration: 27.76 seconds
#   Time range: 683.74s - 711.50s
# --------------------------------------------------
# Saved segment 021 (22/198): training-021.mp3
#   Duration: 27.42 seconds
#   Time range: 712.30s - 739.72s
# --------------------------------------------------
# Saved segment 022 (23/198): training-022.mp3
#   Duration: 28.36 seconds
#   Time range: 753.34s - 781.70s
# --------------------------------------------------
# Saved segment 023 (24/198): training-023.mp3
#   Duration: 24.92 seconds
#   Time range: 782.54s - 807.46s
# --------------------------------------------------
# Saved segment 024 (25/198): training-024.mp3
#   Duration: 30.60 seconds
#   Time range: 860.26s - 890.86s
# --------------------------------------------------
# Saved segment 025 (26/198): training-025.mp3
#   Duration: 30.24 seconds
#   Time range: 890.86s - 921.10s
# --------------------------------------------------
# Saved segment 026 (27/198): training-026.mp3
#   Duration: 31.78 seconds
#   Time range: 921.10s - 952.88s
# --------------------------------------------------
# Saved segment 027 (28/198): training-027.mp3
#   Duration: 30.32 seconds
#   Time range: 952.88s - 983.20s
# --------------------------------------------------
# Saved segment 028 (29/198): training-028.mp3
#   Duration: 30.58 seconds
#   Time range: 983.20s - 1013.78s
# --------------------------------------------------
# Saved segment 029 (30/198): training-029.mp3
#   Duration: 31.04 seconds
#   Time range: 1013.78s - 1044.82s
# --------------------------------------------------
# Saved segment 030 (31/198): training-030.mp3
#   Duration: 31.62 seconds
#   Time range: 1044.82s - 1076.44s
# --------------------------------------------------
# Saved segment 031 (32/198): training-031.mp3
#   Duration: 31.38 seconds
#   Time range: 1076.44s - 1107.82s
# --------------------------------------------------
# Saved segment 032 (33/198): training-032.mp3
#   Duration: 31.60 seconds
#   Time range: 1107.82s - 1139.42s
# --------------------------------------------------
# Saved segment 033 (34/198): training-033.mp3
#   Duration: 31.86 seconds
#   Time range: 1139.42s - 1171.28s
# --------------------------------------------------
# Saved segment 034 (35/198): training-034.mp3
#   Duration: 30.16 seconds
#   Time range: 1171.28s - 1201.44s
# --------------------------------------------------
# Saved segment 035 (36/198): training-035.mp3
#   Duration: 30.34 seconds
#   Time range: 1201.44s - 1231.78s
# --------------------------------------------------
# Saved segment 036 (37/198): training-036.mp3
#   Duration: 31.74 seconds
#   Time range: 1239.66s - 1271.40s
# --------------------------------------------------
# Saved segment 037 (38/198): training-037.mp3
#   Duration: 30.76 seconds
#   Time range: 1271.40s - 1302.16s
# --------------------------------------------------
# Saved segment 038 (39/198): training-038.mp3
#   Duration: 30.76 seconds
#   Time range: 1302.16s - 1332.92s
# --------------------------------------------------
# Saved segment 039 (40/198): training-039.mp3
#   Duration: 30.90 seconds
#   Time range: 1332.92s - 1363.82s
# --------------------------------------------------
# Saved segment 040 (41/198): training-040.mp3
#   Duration: 30.34 seconds
#   Time range: 1363.82s - 1394.16s
# --------------------------------------------------
# Saved segment 041 (42/198): training-041.mp3
#   Duration: 31.34 seconds
#   Time range: 1394.16s - 1425.50s
# --------------------------------------------------
# Saved segment 042 (43/198): training-042.mp3
#   Duration: 30.42 seconds
#   Time range: 1425.50s - 1455.92s
# --------------------------------------------------
# Saved segment 043 (44/198): training-043.mp3
#   Duration: 31.36 seconds
#   Time range: 1455.92s - 1487.28s
# --------------------------------------------------
# Saved segment 044 (45/198): training-044.mp3
#   Duration: 30.38 seconds
#   Time range: 1487.28s - 1517.66s
# --------------------------------------------------
# Saved segment 045 (46/198): training-045.mp3
#   Duration: 30.48 seconds
#   Time range: 1517.66s - 1548.14s
# --------------------------------------------------
# Saved segment 046 (47/198): training-046.mp3
#   Duration: 30.94 seconds
#   Time range: 1548.14s - 1579.08s
# --------------------------------------------------
# Saved segment 047 (48/198): training-047.mp3
#   Duration: 30.70 seconds
#   Time range: 1579.08s - 1609.78s
# --------------------------------------------------
# Saved segment 048 (49/198): training-048.mp3
#   Duration: 30.64 seconds
#   Time range: 1609.78s - 1640.42s
# --------------------------------------------------
# Saved segment 049 (50/198): training-049.mp3
#   Duration: 30.52 seconds
#   Time range: 1640.42s - 1670.94s
# --------------------------------------------------
# Saved segment 050 (51/198): training-050.mp3
#   Duration: 30.80 seconds
#   Time range: 1670.94s - 1701.74s
# --------------------------------------------------
# Saved segment 051 (52/198): training-051.mp3
#   Duration: 32.28 seconds
#   Time range: 1701.74s - 1734.02s
# --------------------------------------------------
# Saved segment 052 (53/198): training-052.mp3
#   Duration: 30.48 seconds
#   Time range: 1734.02s - 1764.50s
# --------------------------------------------------
# Saved segment 053 (54/198): training-053.mp3
#   Duration: 31.42 seconds
#   Time range: 1764.50s - 1795.92s
# --------------------------------------------------
# Saved segment 054 (55/198): training-054.mp3
#   Duration: 30.28 seconds
#   Time range: 1795.92s - 1826.20s
# --------------------------------------------------
# Saved segment 055 (56/198): training-055.mp3
#   Duration: 31.24 seconds
#   Time range: 1826.20s - 1857.44s
# --------------------------------------------------
# Saved segment 056 (57/198): training-056.mp3
#   Duration: 31.34 seconds
#   Time range: 1857.44s - 1888.78s
# --------------------------------------------------
# Saved segment 057 (58/198): training-057.mp3
#   Duration: 30.60 seconds
#   Time range: 1888.78s - 1919.38s
# --------------------------------------------------
# Saved segment 058 (59/198): training-058.mp3
#   Duration: 32.14 seconds
#   Time range: 1919.38s - 1951.52s
# --------------------------------------------------
# Saved segment 059 (60/198): training-059.mp3
#   Duration: 31.70 seconds
#   Time range: 1959.48s - 1991.18s
# --------------------------------------------------
# Saved segment 060 (61/198): training-060.mp3
#   Duration: 31.16 seconds
#   Time range: 1991.18s - 2022.34s
# --------------------------------------------------
# Saved segment 061 (62/198): training-061.mp3
#   Duration: 30.10 seconds
#   Time range: 2022.34s - 2052.44s
# --------------------------------------------------
# Saved segment 062 (63/198): training-062.mp3
#   Duration: 30.22 seconds
#   Time range: 2052.44s - 2082.66s
# --------------------------------------------------
# Saved segment 063 (64/198): training-063.mp3
#   Duration: 30.06 seconds
#   Time range: 2082.66s - 2112.72s
# --------------------------------------------------
# Saved segment 064 (65/198): training-064.mp3
#   Duration: 30.18 seconds
#   Time range: 2112.72s - 2142.90s
# --------------------------------------------------
# Saved segment 065 (66/198): training-065.mp3
#   Duration: 30.22 seconds
#   Time range: 2142.90s - 2173.12s
# --------------------------------------------------
# Saved segment 066 (67/198): training-066.mp3
#   Duration: 30.40 seconds
#   Time range: 2173.12s - 2203.52s
# --------------------------------------------------
# Saved segment 067 (68/198): training-067.mp3
#   Duration: 34.06 seconds
#   Time range: 2218.70s - 2252.76s
# --------------------------------------------------
# Saved segment 068 (69/198): training-068.mp3
#   Duration: 25.54 seconds
#   Time range: 2255.04s - 2280.58s
# --------------------------------------------------
# Saved segment 069 (70/198): training-069.mp3
#   Duration: 37.68 seconds
#   Time range: 2324.78s - 2362.46s
# --------------------------------------------------
# Saved segment 070 (71/198): training-070.mp3
#   Duration: 35.22 seconds
#   Time range: 2362.46s - 2397.68s
# --------------------------------------------------
# Saved segment 071 (72/198): training-071.mp3
#   Duration: 33.30 seconds
#   Time range: 2401.70s - 2435.00s
# --------------------------------------------------
# Saved segment 072 (73/198): training-072.mp3
#   Duration: 33.30 seconds
#   Time range: 2466.32s - 2499.62s
# --------------------------------------------------
# Saved segment 073 (74/198): training-073.mp3
#   Duration: 36.20 seconds
#   Time range: 2593.82s - 2630.02s
# --------------------------------------------------
# Saved segment 074 (75/198): training-074.mp3
#   Duration: 32.90 seconds
#   Time range: 3164.70s - 3197.60s
# --------------------------------------------------
# Saved segment 075 (76/198): training-075.mp3
#   Duration: 29.26 seconds
#   Time range: 3198.24s - 3227.50s
# --------------------------------------------------
# Saved segment 076 (77/198): training-076.mp3
#   Duration: 32.70 seconds
#   Time range: 3228.10s - 3260.80s
# --------------------------------------------------
# Saved segment 077 (78/198): training-077.mp3
#   Duration: 30.40 seconds
#   Time range: 3260.80s - 3291.20s
# --------------------------------------------------
# Saved segment 078 (79/198): training-078.mp3
#   Duration: 30.84 seconds
#   Time range: 3291.20s - 3322.04s
# --------------------------------------------------
# Saved segment 079 (80/198): training-079.mp3
#   Duration: 31.34 seconds
#   Time range: 3322.04s - 3353.38s
# --------------------------------------------------
# Saved segment 080 (81/198): training-080.mp3
#   Duration: 30.98 seconds
#   Time range: 3353.38s - 3384.36s
# --------------------------------------------------
# Saved segment 081 (82/198): training-081.mp3
#   Duration: 30.48 seconds
#   Time range: 3384.36s - 3414.84s
# --------------------------------------------------
# Saved segment 082 (83/198): training-082.mp3
#   Duration: 33.68 seconds
#   Time range: 3414.84s - 3448.52s
# --------------------------------------------------
# Saved segment 083 (84/198): training-083.mp3
#   Duration: 34.52 seconds
#   Time range: 3453.42s - 3487.94s
# --------------------------------------------------
# Saved segment 084 (85/198): training-084.mp3
#   Duration: 33.94 seconds
#   Time range: 3617.44s - 3651.38s
# --------------------------------------------------
# Saved segment 085 (86/198): training-085.mp3
#   Duration: 31.08 seconds
#   Time range: 3702.52s - 3733.60s
# --------------------------------------------------
# Saved segment 086 (87/198): training-086.mp3
#   Duration: 35.72 seconds
#   Time range: 3734.24s - 3769.96s
# --------------------------------------------------
# Saved segment 087 (88/198): training-087.mp3
#   Duration: 34.10 seconds
#   Time range: 3774.32s - 3808.42s
# --------------------------------------------------
# Saved segment 088 (89/198): training-088.mp3
#   Duration: 23.68 seconds
#   Time range: 3907.82s - 3931.50s
# --------------------------------------------------
# Saved segment 089 (90/198): training-089.mp3
#   Duration: 23.16 seconds
#   Time range: 4009.84s - 4033.00s
# --------------------------------------------------
# Saved segment 090 (91/198): training-090.mp3
#   Duration: 27.64 seconds
#   Time range: 4061.00s - 4088.64s
# --------------------------------------------------
# Saved segment 091 (92/198): training-091.mp3
#   Duration: 33.24 seconds
#   Time range: 4089.50s - 4122.74s
# --------------------------------------------------
# Saved segment 092 (93/198): training-092.mp3
#   Duration: 23.76 seconds
#   Time range: 4122.74s - 4146.50s
# --------------------------------------------------
# Saved segment 093 (94/198): training-093.mp3
#   Duration: 32.00 seconds
#   Time range: 4147.16s - 4179.16s
# --------------------------------------------------
# Saved segment 094 (95/198): training-094.mp3
#   Duration: 33.08 seconds
#   Time range: 4210.08s - 4243.16s
# --------------------------------------------------
# Saved segment 095 (96/198): training-095.mp3
#   Duration: 32.42 seconds
#   Time range: 4293.10s - 4325.52s
# --------------------------------------------------
# Saved segment 096 (97/198): training-096.mp3
#   Duration: 32.56 seconds
#   Time range: 4335.72s - 4368.28s
# --------------------------------------------------
# Saved segment 097 (98/198): training-097.mp3
#   Duration: 33.36 seconds
#   Time range: 4368.84s - 4402.20s
# --------------------------------------------------
# Saved segment 098 (99/198): training-098.mp3
#   Duration: 32.40 seconds
#   Time range: 4402.20s - 4434.60s
# --------------------------------------------------
# Saved segment 099 (100/198): training-099.mp3
#   Duration: 24.78 seconds
#   Time range: 4444.26s - 4469.04s
# --------------------------------------------------
# Saved segment 100 (101/198): training-100.mp3
#   Duration: 24.04 seconds
#   Time range: 4474.54s - 4498.58s
# --------------------------------------------------
# Saved segment 101 (102/198): training-101.mp3
#   Duration: 35.14 seconds
#   Time range: 4509.92s - 4545.06s
# --------------------------------------------------
# Saved segment 102 (103/198): training-102.mp3
#   Duration: 31.84 seconds
#   Time range: 4590.04s - 4621.88s
# --------------------------------------------------
# Saved segment 103 (104/198): training-103.mp3
#   Duration: 32.60 seconds
#   Time range: 4621.88s - 4654.48s
# --------------------------------------------------
# Saved segment 104 (105/198): training-104.mp3
#   Duration: 29.40 seconds
#   Time range: 4704.56s - 4733.96s
# --------------------------------------------------
# Saved segment 105 (106/198): training-105.mp3
#   Duration: 31.70 seconds
#   Time range: 4742.54s - 4774.24s
# --------------------------------------------------
# Saved segment 106 (107/198): training-106.mp3
#   Duration: 32.44 seconds
#   Time range: 4793.58s - 4826.02s
# --------------------------------------------------
# Saved segment 107 (108/198): training-107.mp3
#   Duration: 33.26 seconds
#   Time range: 4852.16s - 4885.42s
# --------------------------------------------------
# Saved segment 108 (109/198): training-108.mp3
#   Duration: 28.26 seconds
#   Time range: 4886.04s - 4914.30s
# --------------------------------------------------
# Saved segment 109 (110/198): training-109.mp3
#   Duration: 23.90 seconds
#   Time range: 4919.24s - 4943.14s
# --------------------------------------------------
# Saved segment 110 (111/198): training-110.mp3
#   Duration: 30.60 seconds
#   Time range: 4944.06s - 4974.66s
# --------------------------------------------------
# Saved segment 111 (112/198): training-111.mp3
#   Duration: 32.16 seconds
#   Time range: 4974.66s - 5006.82s
# --------------------------------------------------
# Saved segment 112 (113/198): training-112.mp3
#   Duration: 33.02 seconds
#   Time range: 5006.82s - 5039.84s
# --------------------------------------------------
# Saved segment 113 (114/198): training-113.mp3
#   Duration: 29.74 seconds
#   Time range: 5056.76s - 5086.50s
# --------------------------------------------------
# Saved segment 114 (115/198): training-114.mp3
#   Duration: 31.58 seconds
#   Time range: 5145.16s - 5176.74s
# --------------------------------------------------
# Saved segment 115 (116/198): training-115.mp3
#   Duration: 32.06 seconds
#   Time range: 5176.74s - 5208.80s
# --------------------------------------------------
# Saved segment 116 (117/198): training-116.mp3
#   Duration: 30.76 seconds
#   Time range: 5208.80s - 5239.56s
# --------------------------------------------------
# Saved segment 117 (118/198): training-117.mp3
#   Duration: 30.60 seconds
#   Time range: 5239.56s - 5270.16s
# --------------------------------------------------
# Saved segment 118 (119/198): training-118.mp3
#   Duration: 30.68 seconds
#   Time range: 5270.16s - 5300.84s
# --------------------------------------------------
# Saved segment 119 (120/198): training-119.mp3
#   Duration: 30.74 seconds
#   Time range: 5300.84s - 5331.58s
# --------------------------------------------------
# Saved segment 120 (121/198): training-120.mp3
#   Duration: 30.46 seconds
#   Time range: 5331.58s - 5362.04s
# --------------------------------------------------
# Saved segment 121 (122/198): training-121.mp3
#   Duration: 31.62 seconds
#   Time range: 5362.04s - 5393.66s
# --------------------------------------------------
# Saved segment 122 (123/198): training-122.mp3
#   Duration: 31.56 seconds
#   Time range: 5393.66s - 5425.22s
# --------------------------------------------------
# Saved segment 123 (124/198): training-123.mp3
#   Duration: 32.48 seconds
#   Time range: 5425.22s - 5457.70s
# --------------------------------------------------
# Saved segment 124 (125/198): training-124.mp3
#   Duration: 32.78 seconds
#   Time range: 5457.70s - 5490.48s
# --------------------------------------------------
# Saved segment 125 (126/198): training-125.mp3
#   Duration: 32.06 seconds
#   Time range: 5490.48s - 5522.54s
# --------------------------------------------------
# Saved segment 126 (127/198): training-126.mp3
#   Duration: 23.66 seconds
#   Time range: 5533.14s - 5556.80s
# --------------------------------------------------
# Saved segment 127 (128/198): training-127.mp3
#   Duration: 32.30 seconds
#   Time range: 5557.36s - 5589.66s
# --------------------------------------------------
# Saved segment 128 (129/198): training-128.mp3
#   Duration: 30.20 seconds
#   Time range: 5589.66s - 5619.86s
# --------------------------------------------------
# Saved segment 129 (130/198): training-129.mp3
#   Duration: 30.62 seconds
#   Time range: 5619.86s - 5650.48s
# --------------------------------------------------
# Saved segment 130 (131/198): training-130.mp3
#   Duration: 31.22 seconds
#   Time range: 5650.48s - 5681.70s
# --------------------------------------------------
# Saved segment 131 (132/198): training-131.mp3
#   Duration: 31.98 seconds
#   Time range: 5681.70s - 5713.68s
# --------------------------------------------------
# Saved segment 132 (133/198): training-132.mp3
#   Duration: 30.30 seconds
#   Time range: 5713.68s - 5743.98s
# --------------------------------------------------
# Saved segment 133 (134/198): training-133.mp3
#   Duration: 30.38 seconds
#   Time range: 5743.98s - 5774.36s
# --------------------------------------------------
# Saved segment 134 (135/198): training-134.mp3
#   Duration: 30.28 seconds
#   Time range: 5774.36s - 5804.64s
# --------------------------------------------------
# Saved segment 135 (136/198): training-135.mp3
#   Duration: 30.88 seconds
#   Time range: 5804.64s - 5835.52s
# --------------------------------------------------
# Saved segment 136 (137/198): training-136.mp3
#   Duration: 30.24 seconds
#   Time range: 5835.52s - 5865.76s
# --------------------------------------------------
# Saved segment 137 (138/198): training-137.mp3
#   Duration: 30.40 seconds
#   Time range: 5865.76s - 5896.16s
# --------------------------------------------------
# Saved segment 138 (139/198): training-138.mp3
#   Duration: 30.68 seconds
#   Time range: 5896.16s - 5926.84s
# --------------------------------------------------
# Saved segment 139 (140/198): training-139.mp3
#   Duration: 31.12 seconds
#   Time range: 5926.84s - 5957.96s
# --------------------------------------------------
# Saved segment 140 (141/198): training-140.mp3
#   Duration: 30.80 seconds
#   Time range: 5957.96s - 5988.76s
# --------------------------------------------------
# Saved segment 141 (142/198): training-141.mp3
#   Duration: 30.08 seconds
#   Time range: 5988.76s - 6018.84s
# --------------------------------------------------
# Saved segment 142 (143/198): training-142.mp3
#   Duration: 31.72 seconds
#   Time range: 6018.84s - 6050.56s
# --------------------------------------------------
# Saved segment 143 (144/198): training-143.mp3
#   Duration: 28.48 seconds
#   Time range: 6050.56s - 6079.04s
# --------------------------------------------------
# Saved segment 144 (145/198): training-144.mp3
#   Duration: 32.28 seconds
#   Time range: 6079.62s - 6111.90s
# --------------------------------------------------
# Saved segment 145 (146/198): training-145.mp3
#   Duration: 32.14 seconds
#   Time range: 6122.80s - 6154.94s
# --------------------------------------------------
# Saved segment 146 (147/198): training-146.mp3
#   Duration: 32.10 seconds
#   Time range: 6154.94s - 6187.04s
# --------------------------------------------------
# Saved segment 147 (148/198): training-147.mp3
#   Duration: 32.98 seconds
#   Time range: 6187.04s - 6220.02s
# --------------------------------------------------
# Saved segment 148 (149/198): training-148.mp3
#   Duration: 32.98 seconds
#   Time range: 6220.02s - 6253.00s
# --------------------------------------------------
# Saved segment 149 (150/198): training-149.mp3
#   Duration: 31.92 seconds
#   Time range: 6253.00s - 6284.92s
# --------------------------------------------------
# Saved segment 150 (151/198): training-150.mp3
#   Duration: 24.62 seconds
#   Time range: 6284.92s - 6309.54s
# --------------------------------------------------
# Saved segment 151 (152/198): training-151.mp3
#   Duration: 30.38 seconds
#   Time range: 6311.54s - 6341.92s
# --------------------------------------------------
# Saved segment 152 (153/198): training-152.mp3
#   Duration: 30.64 seconds
#   Time range: 6341.92s - 6372.56s
# --------------------------------------------------
# Saved segment 153 (154/198): training-153.mp3
#   Duration: 30.36 seconds
#   Time range: 6372.56s - 6402.92s
# --------------------------------------------------
# Saved segment 154 (155/198): training-154.mp3
#   Duration: 30.36 seconds
#   Time range: 6402.92s - 6433.28s
# --------------------------------------------------
# Saved segment 155 (156/198): training-155.mp3
#   Duration: 30.26 seconds
#   Time range: 6433.28s - 6463.54s
# --------------------------------------------------
# Saved segment 156 (157/198): training-156.mp3
#   Duration: 30.40 seconds
#   Time range: 6463.54s - 6493.94s
# --------------------------------------------------
# Saved segment 157 (158/198): training-157.mp3
#   Duration: 30.20 seconds
#   Time range: 6493.94s - 6524.14s
# --------------------------------------------------
# Saved segment 158 (159/198): training-158.mp3
#   Duration: 30.14 seconds
#   Time range: 6524.14s - 6554.28s
# --------------------------------------------------
# Saved segment 159 (160/198): training-159.mp3
#   Duration: 30.24 seconds
#   Time range: 6554.28s - 6584.52s
# --------------------------------------------------
# Saved segment 160 (161/198): training-160.mp3
#   Duration: 30.44 seconds
#   Time range: 6584.52s - 6614.96s
# --------------------------------------------------
# Saved segment 161 (162/198): training-161.mp3
#   Duration: 30.76 seconds
#   Time range: 6614.96s - 6645.72s
# --------------------------------------------------
# Saved segment 162 (163/198): training-162.mp3
#   Duration: 30.24 seconds
#   Time range: 6645.72s - 6675.96s
# --------------------------------------------------
# Saved segment 163 (164/198): training-163.mp3
#   Duration: 30.50 seconds
#   Time range: 6675.96s - 6706.46s
# --------------------------------------------------
# Saved segment 164 (165/198): training-164.mp3
#   Duration: 30.54 seconds
#   Time range: 6706.46s - 6737.00s
# --------------------------------------------------
# Saved segment 165 (166/198): training-165.mp3
#   Duration: 30.34 seconds
#   Time range: 6737.00s - 6767.34s
# --------------------------------------------------
# Saved segment 166 (167/198): training-166.mp3
#   Duration: 30.44 seconds
#   Time range: 6767.34s - 6797.78s
# --------------------------------------------------
# Saved segment 167 (168/198): training-167.mp3
#   Duration: 30.34 seconds
#   Time range: 6797.78s - 6828.12s
# --------------------------------------------------
# Saved segment 168 (169/198): training-168.mp3
#   Duration: 30.32 seconds
#   Time range: 6828.12s - 6858.44s
# --------------------------------------------------
# Saved segment 169 (170/198): training-169.mp3
#   Duration: 30.10 seconds
#   Time range: 6858.44s - 6888.54s
# --------------------------------------------------
# Saved segment 170 (171/198): training-170.mp3
#   Duration: 30.42 seconds
#   Time range: 6888.54s - 6918.96s
# --------------------------------------------------
# Saved segment 171 (172/198): training-171.mp3
#   Duration: 30.16 seconds
#   Time range: 6918.96s - 6949.12s
# --------------------------------------------------
# Saved segment 172 (173/198): training-172.mp3
#   Duration: 30.34 seconds
#   Time range: 6949.12s - 6979.46s
# --------------------------------------------------
# Saved segment 173 (174/198): training-173.mp3
#   Duration: 30.30 seconds
#   Time range: 6979.46s - 7009.76s
# --------------------------------------------------
# Saved segment 174 (175/198): training-174.mp3
#   Duration: 29.80 seconds
#   Time range: 7314.30s - 7344.10s
# --------------------------------------------------
# Saved segment 175 (176/198): training-175.mp3
#   Duration: 33.64 seconds
#   Time range: 7352.96s - 7386.60s
# --------------------------------------------------
# Saved segment 176 (177/198): training-176.mp3
#   Duration: 35.06 seconds
#   Time range: 7435.54s - 7470.60s
# --------------------------------------------------
# Saved segment 177 (178/198): training-177.mp3
#   Duration: 34.48 seconds
#   Time range: 7551.18s - 7585.66s
# --------------------------------------------------
# Saved segment 178 (179/198): training-178.mp3
#   Duration: 26.08 seconds
#   Time range: 7700.20s - 7726.28s
# --------------------------------------------------
# Saved segment 179 (180/198): training-179.mp3
#   Duration: 23.04 seconds
#   Time range: 7977.12s - 8000.16s
# --------------------------------------------------
# Saved segment 180 (181/198): training-180.mp3
#   Duration: 30.00 seconds
#   Time range: 8630.86s - 8660.86s
# --------------------------------------------------
# Saved segment 181 (182/198): training-181.mp3
#   Duration: 28.10 seconds
#   Time range: 8769.42s - 8797.52s
# --------------------------------------------------
# Saved segment 182 (183/198): training-182.mp3
#   Duration: 37.50 seconds
#   Time range: 8910.10s - 8947.60s
# --------------------------------------------------
# Saved segment 183 (184/198): training-183.mp3
#   Duration: 24.02 seconds
#   Time range: 8947.60s - 8971.62s
# --------------------------------------------------
# Saved segment 184 (185/198): training-184.mp3
#   Duration: 32.94 seconds
#   Time range: 8972.78s - 9005.72s
# --------------------------------------------------
# Saved segment 185 (186/198): training-185.mp3
#   Duration: 33.00 seconds
#   Time range: 9072.96s - 9105.96s
# --------------------------------------------------
# Saved segment 186 (187/198): training-186.mp3
#   Duration: 22.66 seconds
#   Time range: 9167.94s - 9190.60s
# --------------------------------------------------
# Saved segment 187 (188/198): training-187.mp3
#   Duration: 31.90 seconds
#   Time range: 9237.28s - 9269.18s
# --------------------------------------------------
# Saved segment 188 (189/198): training-188.mp3
#   Duration: 22.74 seconds
#   Time range: 9284.78s - 9307.52s
# --------------------------------------------------
# Saved segment 189 (190/198): training-189.mp3
#   Duration: 32.96 seconds
#   Time range: 9340.76s - 9373.72s
# --------------------------------------------------
# Saved segment 190 (191/198): training-190.mp3
#   Duration: 29.44 seconds
#   Time range: 9373.72s - 9403.16s
# --------------------------------------------------
# Saved segment 191 (192/198): training-191.mp3
#   Duration: 23.08 seconds
#   Time range: 9523.52s - 9546.60s
# --------------------------------------------------
# Saved segment 192 (193/198): training-192.mp3
#   Duration: 31.38 seconds
#   Time range: 9649.10s - 9680.48s
# --------------------------------------------------
# Saved segment 193 (194/198): training-193.mp3
#   Duration: 32.38 seconds
#   Time range: 9680.48s - 9712.86s
# --------------------------------------------------
# Saved segment 194 (195/198): training-194.mp3
#   Duration: 32.08 seconds
#   Time range: 9712.86s - 9744.94s
# --------------------------------------------------
# Saved segment 195 (196/198): training-195.mp3
#   Duration: 32.44 seconds
#   Time range: 9759.80s - 9792.24s
# --------------------------------------------------
# Saved segment 196 (197/198): training-196.mp3
#   Duration: 32.44 seconds
#   Time range: 9792.24s - 9824.68s
# --------------------------------------------------
# Saved segment 197 (198/198): training-197.mp3
#   Duration: 32.72 seconds
#   Time range: 9824.68s - 9857.40s
# --------------------------------------------------
#
# Processing complete!
# Created 198 segments.
#
# Saved files:
# - training-000.mp3
# - training-001.mp3
# - training-002.mp3
# - training-003.mp3
# - training-004.mp3
# - training-005.mp3
# - training-006.mp3
# - training-007.mp3
# - training-008.mp3
# - training-009.mp3
# - training-010.mp3
# - training-011.mp3
# - training-012.mp3
# - training-013.mp3
# - training-014.mp3
# - training-015.mp3
# - training-016.mp3
# - training-017.mp3
# - training-018.mp3
# - training-019.mp3
# - training-020.mp3
# - training-021.mp3
# - training-022.mp3
# - training-023.mp3
# - training-024.mp3
# - training-025.mp3
# - training-026.mp3
# - training-027.mp3
# - training-028.mp3
# - training-029.mp3
# - training-030.mp3
# - training-031.mp3
# - training-032.mp3
# - training-033.mp3
# - training-034.mp3
# - training-035.mp3
# - training-036.mp3
# - training-037.mp3
# - training-038.mp3
# - training-039.mp3
# - training-040.mp3
# - training-041.mp3
# - training-042.mp3
# - training-043.mp3
# - training-044.mp3
# - training-045.mp3
# - training-046.mp3
# - training-047.mp3
# - training-048.mp3
# - training-049.mp3
# - training-050.mp3
# - training-051.mp3
# - training-052.mp3
# - training-053.mp3
# - training-054.mp3
# - training-055.mp3
# - training-056.mp3
# - training-057.mp3
# - training-058.mp3
# - training-059.mp3
# - training-060.mp3
# - training-061.mp3
# - training-062.mp3
# - training-063.mp3
# - training-064.mp3
# - training-065.mp3
# - training-066.mp3
# - training-067.mp3
# - training-068.mp3
# - training-069.mp3
# - training-070.mp3
# - training-071.mp3
# - training-072.mp3
# - training-073.mp3
# - training-074.mp3
# - training-075.mp3
# - training-076.mp3
# - training-077.mp3
# - training-078.mp3
# - training-079.mp3
# - training-080.mp3
# - training-081.mp3
# - training-082.mp3
# - training-083.mp3
# - training-084.mp3
# - training-085.mp3
# - training-086.mp3
# - training-087.mp3
# - training-088.mp3
# - training-089.mp3
# - training-090.mp3
# - training-091.mp3
# - training-092.mp3
# - training-093.mp3
# - training-094.mp3
# - training-095.mp3
# - training-096.mp3
# - training-097.mp3
# - training-098.mp3
# - training-099.mp3
# - training-100.mp3
# - training-101.mp3
# - training-102.mp3
# - training-103.mp3
# - training-104.mp3
# - training-105.mp3
# - training-106.mp3
# - training-107.mp3
# - training-108.mp3
# - training-109.mp3
# - training-110.mp3
# - training-111.mp3
# - training-112.mp3
# - training-113.mp3
# - training-114.mp3
# - training-115.mp3
# - training-116.mp3
# - training-117.mp3
# - training-118.mp3
# - training-119.mp3
# - training-120.mp3
# - training-121.mp3
# - training-122.mp3
# - training-123.mp3
# - training-124.mp3
# - training-125.mp3
# - training-126.mp3
# - training-127.mp3
# - training-128.mp3
# - training-129.mp3
# - training-130.mp3
# - training-131.mp3
# - training-132.mp3
# - training-133.mp3
# - training-134.mp3
# - training-135.mp3
# - training-136.mp3
# - training-137.mp3
# - training-138.mp3
# - training-139.mp3
# - training-140.mp3
# - training-141.mp3
# - training-142.mp3
# - training-143.mp3
# - training-144.mp3
# - training-145.mp3
# - training-146.mp3
# - training-147.mp3
# - training-148.mp3
# - training-149.mp3
# - training-150.mp3
# - training-151.mp3
# - training-152.mp3
# - training-153.mp3
# - training-154.mp3
# - training-155.mp3
# - training-156.mp3
# - training-157.mp3
# - training-158.mp3
# - training-159.mp3
# - training-160.mp3
# - training-161.mp3
# - training-162.mp3
# - training-163.mp3
# - training-164.mp3
# - training-165.mp3
# - training-166.mp3
# - training-167.mp3
# - training-168.mp3
# - training-169.mp3
# - training-170.mp3
# - training-171.mp3
# - training-172.mp3
# - training-173.mp3
# - training-174.mp3
# - training-175.mp3
# - training-176.mp3
# - training-177.mp3
# - training-178.mp3
# - training-179.mp3
# - training-180.mp3
# - training-181.mp3
# - training-182.mp3
# - training-183.mp3
# - training-184.mp3
# - training-185.mp3
# - training-186.mp3
# - training-187.mp3
# - training-188.mp3
# - training-189.mp3
# - training-190.mp3
# - training-191.mp3
# - training-192.mp3
# - training-193.mp3
# - training-194.mp3
# - training-195.mp3
# - training-196.mp3
# - training-197.mp3
